# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import json
connection_string = "mongodb+srv://Myapp:tushar123@cluster0.8cmoey2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(connection_string)
db = client['live']

collection = db['sensor']
data = {"name":"Tushar","age":56,"email":"tukumawat73@gmail.com"}

# %%
connection_string = "mongodb+srv://Myapp:tushar123@cluster0.8cmoey2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(connection_string)
db = client['live']

collection = db['sensor']

# %%
data = {"name":"Tushar","age":56,"email":"tukumawat73@gmail.com"}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6a6e32802961fcef259cbcba'), acknowledged=True)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('6a6e29d32961fcef259cbcb6'), 'name': 'Tushar', 'age': 56, 'email': 'tukumawat73@gmail.com'}
